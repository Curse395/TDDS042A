# %%
import nltk

# %%
from nltk.corpus import brown

# %%
nltk.download("brown")
print("Categories :",brown.categories())
# Out:
# [nltk_data] Downloading package brown to C:\Users\BSCIT
# [nltk_data]     12\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\brown.zip.
# Categories : ['adventure', 'belles_lettres', 'editorial', 'fiction', 'government', 'hobbies', 'humor', 'learned', 'lore', 'mystery', 'news', 'religion', 'reviews', 'romance', 'science_fiction']

# %%
humor_words= brown.words(categories ='humor')

# %%
print("First 20 words from the 'humor'category:",humor_words[0:20])
# Out:
# First 20 words from the 'humor'category: ['It', 'was', 'among', 'these', 'that', 'Hinkle', 'identified', 'a', 'photograph', 'of', 'Barco', '!', '!', 'For', 'it', 'seems', 'that', 'Barco', ',', 'fancying']
