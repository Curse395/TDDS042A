# %%
import re

# %%
pattern = r"\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+[A-Za-z]{2,}\b"

# %%
email = input("Enter your email")
# Out:
# Enter your emailbsadv47*@gmail.com

# %%
match = re.match(pattern ,email)

# %%
if match:
    print("email id is valid")
else:
    print("email is invalid")
# Out:
# email is invalid
